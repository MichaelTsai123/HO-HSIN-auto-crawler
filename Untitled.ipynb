# %%
from keras import utils
import numpy as np
from keras.layers import Dense,Dropout,Flatten,Conv2D,MaxPooling2D,Input, GlobalAveragePooling2D
from keras.models import Sequential,Model
from keras.applications.inception_v3 import InceptionV3

from os import listdir
from os.path import isfile, isdir, join

import re

train_picture = []
train_label = []

x_train = []
x_label = []

def make_model():
    # create the base pre-trained model
    #base_model = InceptionV3(include_top=False)

    # add a global spatial average pooling layer
    #x1 = base_model.output
    x1 = Input(shape=(300,300,3)
    x2 = GlobalAveragePooling2D()(x1)
    # let's add a fully-connected layer
    x3 = Dense(1024, activation='relu')(x2)
    # and a logistic layer -- let's say we have 200 classes
    predictions = Dense(200, activation='softmax')(x3)
    

    # this is the model we will train
    model = Model(inputs=base_model.input, outputs=predictions)
    
    model.summary()
    #for layer in base_model.layers:
    #    layer.trainable = False

    return model

    

def make_dataset(picture,label,mypath):
    files = listdir(mypath)
    for f in files:
        fullpath = join(mypath, f)
        if isfile(fullpath):
            print(f+" is added !")
            train_picture.append(f)
            
            if(f[0].isdigit()):
                train_label.append(1)
            else:
                train_label.append(0)
            
            
    x_train = np.asarray(train_picture)   
    x_label = utils.to_categorical(train_label)

    
def train():
    
    model = make_model()
    
    model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
    
    model.fit(x_train, x_label,
          epochs=3, batch_size=16)

# %%
make_dataset(train_picture,train_label,'training_data')
# Out:
# 0353.png is added !
# 2140.png is added !
# 4451.png is added !
# 6227.png is added !
# 6933.png is added !
# 8244.png is added !
# bkak.png is added !
# jpuz.png is added !
# pjui.png is added !
# rnen.png is added !
# xyow.png is added !

# %%
train()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_16 (InputLayer)           (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv2d_970 (Conv2D)             (None, None, None, 3 864         input_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_968 (BatchN (None, None, None, 3 96          conv2d_970[0][0]
# __________________________________________________________________________________________________
# activation_968 (Activation)     (None, None, None, 3 0           batch_normalization_968[0][0]
# __________________________________________________________________________________________________
# conv2d_971 (Conv2D)             (None, None, None, 3 9216        activation_968[0][0]
# ...
